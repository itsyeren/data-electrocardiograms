# %% [markdown]
# # Electrocardiogram Classification

# %% [markdown]
# ## (1) Electrocardiograms

# %% [markdown]
# 👇 Import the [`electrocardiograms.csv`](https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/ML_Electrocardiograms_dataset.csv) dataset and display the first 5 rows

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# !curl -s https://d32aokrjazspmn.cloudfront.net/materials/ML_Electrocardiograms_dataset.csv

data = pd.read_csv('data/electrocardiograms.csv')

data.head()

# %% [markdown]
# 💓 Each observation in the dataset is a sequence of measured heartbeats taken from a patient's electrocardiogram (ECG).
#
# 🎯 The target is binary and indicates whether the heartbeat shows:
# * risk of cardiovascular disease 🔴 (1)
# * no risk otherwise 🟢 (0)

# %% [markdown]
# ## (2) Data Exploration

# %% [markdown]
# ❓ **Question** ❓
#
# Plot one observation from each target class to get a visual sense of what the numbers represent.

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Questions** ❓
#
# * How many at-risk heartbeat observations are there? Save your answer as `at_risk_count`.

# %%
# YOUR CODE HERE

# %% [markdown]
# * How many healthy heartbeat observations are there? Save your answer as `healthy_count`.

# %%
# YOUR CODE HERE

# %% [markdown]
# 👩🏻‍🏫 In certain situations, the class balance represents the real-world class distribution. This is the case here: the vast majority of people actually have healthy hearts. In this case, we preserve the class distribution to train the model on reality and adapt our modeling approach accordingly.
#
# [Centers for Disease Control and Prevention - Heart Disease Facts](https://www.cdc.gov/heartdisease/facts.htm)

# %% [markdown]
# 🧪 **Check your code**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('class_balance',
                         healthy = healthy_count,
                         at_risk = at_risk_count)
result.write()
print(result.check())

# %% [markdown]
# ##  (3) Logistic Regression

# %% [markdown]
# 🎯 Your task is to **flag heartbeats at risk of cardiovascular disease.**
#
# 👇 Let's start by exploring the performance of `LogisticRegression` on this task. ***Use cross-validation*** to evaluate the model on the following metrics:
# - Accuracy
# - Recall
# - Precision
# - F1

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Question (Ratio of correct predictions)** ❓
#
# What is the ratio of correct predictions for this model? Save your answer as `correct_pred_ratio`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Question (Ability to flag at-risk patients)** ❓
#
# What percentage of at-risk heartbeats can the model flag? Save your answer as `flag_ratio`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Question (Ability to flag correctly)** ❓
#
# When the model signals a heartbeat as at-risk, how often is it correct? Save your answer as `correct_detection_ratio`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Question (Detecting as many at-risk patients as possible without too many false alarms)** ❓
#
# What is the model's ability to flag as many at-risk heartbeats as possible while limiting false alarms? Save your answer as `aggregated_metric`.

# %%
# YOUR CODE HERE

# %% [markdown]
# 🧪 **Check your code**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('logistic_regression_evaluation',
                         accuracy = correct_pred_ratio,
                         recall = flag_ratio,
                         precision = correct_detection_ratio,
                         f1 = aggregated_metric)
result.write()
print(result.check())

# %% [markdown]
# ▶️ Run the cell below before continuing:

# %%
print(f"You should have noticed that the model was able to predict correctly in {int(round(correct_pred_ratio,2)*100)} cases out of 100. ")

print(f"However, it was able to capture only {round(flag_ratio,2)*100} % of the at-risk patients")

print("Why ? Let's print a confusion matrix!")

# %% [markdown]
# ## (4) Confusion Matrix

# %% [markdown]
# 👇 Using `ConfusionMatrixDisplay` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay)), visualize the prediction breakdown of the Logistic Regression model.

# %% [markdown]
# <details>
# <summary>💡 Hints</summary>
#
#
# 1. [from_estimator](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay.from_estimator)
# 2. [from_predictions](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay.from_predictions)
#
# - Remember to go back to the **Holdout method** to split your dataset with [`train-test-split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) and look at the confusion matrix on the test set.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ℹ️ The confusion matrix should show that the model is affected by class imbalance: it predicts heartbeats as healthy most of the time. Because of this behavior, the model is often correct and has **high accuracy**. However, this also causes it to miss many at-risk heartbeats: it has a **poor recall** score...
#
# 👉 This is why this model is weak at the task of **flagging at-risk observations**.
#
# ❗️ Don't be fooled by accuracy — look at the metric that corresponds to your task! ❗️

# %% [markdown]
# ## (5) KNN Classifier

# %% [markdown]
# ❓ **Question (Classification Model Selection)** ❓
#
# Does a default KNN classifier perform better at the task of flagging at-risk observations?
#
# Save your answer as `best_model` using either "KNN" or "LogisticRegression".

# %%
# YOUR CODE HERE

# %% [markdown]
# 💪 For this ECG dataset, the KNN Classifier should have a much higher recall than LogisticRegression, and is therefore better suited for the task.

# %% [markdown]
# 🧪 **Check your code**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('best_model',
                         model = best_model)
result.write()
print(result.check())

# %% [markdown]
# ## (6) Classification Report

# %% [markdown]
# Now that we have selected the KNN model for its higher recall, let's look at the other classification performance metrics.

# %% [markdown]
# ❓ **Question (Classification Report)** ❓
#
# Print the [`classification_report`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html) of the KNN model.

# %% [markdown]
# <details>
#     <summary> 💡 <i>Hint</i>  </summary>
#
# * You'll need to pass the model's predictions to a `classification_report`.
#
# * SkLearn's [`cross_val_predict`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html) might help 😉
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ **Question (Reading the report)** ❓
#
# Among heartbeats predicted as at-risk, what is the proportion of correct predictions?
#
# In mathematical terms, can you read the \( \frac{TP}{TP + FP} \) ratio from the report? What is the name of this classification metric?
#
# Save your answer as a float under `correct_at_risk_predictions`

# %%
# YOUR CODE HERE

# %% [markdown]
# 🧪 **Check your code**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('precision',
                         precision = correct_at_risk_predictions)
result.write()
print(result.check())

# %% [markdown]
# ## (7) Prediction

# %% [markdown]
# ❓ **Question (Making a prediction)** ❓
#
# A patient comes to you for a second opinion because they were told their heartbeats indicate they may be at risk.
#
# According to your optimal model, are they at risk or not?
#
# Save your model's prediction as `prediction` using either "at risk" or "healthy".

# %%
new_patient = pd.read_csv('https://d32aokrjazspmn.cloudfront.net/materials/ML_Electrocardiograms_new_patient.csv')
new_patient

# %%
# YOUR CODE HERE

# %% [markdown]
# 🧪 **Check your code**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('prediction',
                         prediction = prediction)
result.write()
print(result.check())

# %% [markdown]
# 🏁 Congratulations!
#
# 💾 Don't forget to git add/commit/push your notebook...
#
# 🚀 ... and move on to the next challenge!
